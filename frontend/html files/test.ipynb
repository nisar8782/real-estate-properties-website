# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
resp = requests.get('https://www.zivefirmy.cz/genesis_f1776566?q=eshop&loc=1')

# %%
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="cs">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>GENESIS , Valašské Meziříčí, Krásno nad Bečvou - Živéfirmy.cz</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="GENESIS,Valašské Meziříčí,Internetové obchody, e-shopy,Prodej, " name="keywords">
# <meta content="GENESIS , Zašovská 251/7,Valašské Meziříčí,75701 Valašské Meziříčí 1" name="description">
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="Databox s.r.o." name="author">
# <meta content="(c) 2024, Databox s.r.o." name="copyright">
# <meta content="document" name="resource-type"/>
# <meta content="#526474" name="theme-color"/>
# <link href="/images/favicon/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/images/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# ...

# %%
header = {
    'Content-Type': 'application/json'
}
data = {
    'username':'nisar',
    'password':'1234'
}
resp = requests.post('http://127.0.0.1:8000/api/api/token/',json=data,headers=header)

# %%
resp.content
# Out:
# b'{"refresh":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoicmVmcmVzaCIsImV4cCI6MTcxNTY2OTE1OCwiaWF0IjoxNzE1NTgyNzU4LCJqdGkiOiJiODZiYTlkOTdlMGU0OWE4YmZhMDIyYmY5OWFiNzQwYiIsInVzZXJfaWQiOiJuaXNhciJ9.ZxkwUGmv4njJjhVkrAjF_7ygXr8ZCNLrEiOi3L_6hJ0","access":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzE1NTgzMDU4LCJpYXQiOjE3MTU1ODI3NTgsImp0aSI6IjM3MDliZDE4ZDkzZTQyMWI4MmUxMGZjYTZhZWU2ODYwIiwidXNlcl9pZCI6Im5pc2FyIn0.XN4Zu_ZUTJBm6xfgMcjCrUw7IDAqJ3EtVvOBPuCTyPg"}'

# %%
data = {
    'refresh':"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoicmVmcmVzaCIsImV4cCI6MTcxNTY2OTE1OCwiaWF0IjoxNzE1NTgyNzU4LCJqdGkiOiJiODZiYTlkOTdlMGU0OWE4YmZhMDIyYmY5OWFiNzQwYiIsInVzZXJfaWQiOiJuaXNhciJ9.ZxkwUGmv4njJjhVkrAjF_7ygXr8ZCNLrEiOi3L_6hJ0"
}
resp2 = requests.post('http://127.0.0.1:8000/api/api/token/refresh/', json=data)

# %%
resp2.content
# Out:
# b'{"access":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzE1NTgzMTk5LCJpYXQiOjE3MTU1ODI3NTgsImp0aSI6ImUzZDlhYzZmZjFjNjRlZjE5YzAwODg2MDJiZjY3MTkxIiwidXNlcl9pZCI6Im5pc2FyIn0.WKHWOEIHQa7ZUJkfG2G63XHg5sdILJWMz1XkNz5K2BA"}'

# %%
a = """[
    "This studio apartment in Acton's 'Nishi' complex offers contemporary living with sweeping views of Lake Burley Griffin and the Parliamentary Triangle. It's an ideal choice for those looking to become part of the lively inner-city community, making it well-suited for downsizers, first-time homebuyers, and investors.",
    "",
    "FEATURES",
    "",
    "- Studio apartment in a highly central location.",
    "- The bedroom features fold away bed and built-in wardrobes.",
    "- Modern kitchen equipped with stainless steel appliances and a gas cooktop.",
    "- Open floor plan.",
    "- A spacious covered balcony provides expansive views overlooking Lake Burley Griffin and the Brindabellas.",
    "- Secure underground parking for one vehicle.",
    "- Enviable location, with proximity to excellent bars, restaurants, cafes, Canberra City, Lake Burley Griffin, and the Parliamentary Triangle.",
    "",
    "FIGURES (Approximate)",
    "",
    "EER: 6.0",
    "Internal Living Size: 44m²",
    "Balcony Size: 6m²",
    "Units in complex: 220",
    "Year built: 2014",
    "Land Rates: $430 per quarter",
    "Land Tax: $513 per quarter (only applicable if not primary residence)",
    "Body Corporate Rates: $655 per quarter",
    "Rental Estimate: $480 per week"
      ]"""

# %%
a
# Out:
# '[\n    "This studio apartment in Acton\'s \'Nishi\' complex offers contemporary living with sweeping views of Lake Burley Griffin and the Parliamentary Triangle. It\'s an ideal choice for those looking to become part of the lively inner-city community, making it well-suited for downsizers, first-time homebuyers, and investors.",\n    "",\n    "FEATURES",\n    "",\n    "- Studio apartment in a highly central location.",\n    "- The bedroom features fold away bed and built-in wardrobes.",\n    "- Modern kitchen equipped with stainless steel appliances and a gas cooktop.",\n    "- Open floor plan.",\n    "- A spacious covered balcony provides expansive views overlooking Lake Burley Griffin and the Brindabellas.",\n    "- Secure underground parking for one vehicle.",\n    "- Enviable location, with proximity to excellent bars, restaurants, cafes, Canberra City, Lake Burley Griffin, and the Parliamentary Triangle.",\n    "",\n    "FIGURES (Approximate)",\n    "",\n    "EER: 6.0",\n    "I
# ...

# %%
session = requests.Session()

# %%
header = {
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    # 'Accept-Encoding':'gzip, deflate, br, zstd',
    'Accept-Language':'en-US,en;q=0.9',
    'Cache-Control':'no-cache',
    'Pragma':'no-cache',
    'Priority':'u=0, i',
    'Referer':'https://www.bestsecret.com/',
    'Sec-Ch-Ua':'"Chromium";v="124", "Google Chrome";v="124", "Not-A.Brand";v="99"',
    'Sec-Ch-Ua-Mobile':'?0',
    'Sec-Ch-Ua-Platform':'"Windows"',
    'Sec-Fetch-Dest':'document',
    'Sec-Fetch-Mode':'navigate',
    'Sec-Fetch-Site':'same-site',
    'Sec-Fetch-User':'?1',
    'Upgrade-Insecure-Requests':'1',
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'
}
param = {
    'state': 'hKFo2SBNRVUzS2ZDMlJSVFRveF9KRmlSTjd5c3NpMHcySk11VqFur3VuaXZlcnNhbC1sb2dpbqN0aWTZIFg3ejFqazBoZGhsWE5WQTRsUG1JMUZxVlAydzF2OVZqo2NpZNkgblNCbnhKZTZ6ZU9vOThDbDNDVVJXUWNwWHZ1dWg0OW8',
    'ui_locales': 'en'
}
resp = session.get('https://login.bestsecret.com/u/login',headers=header,params=param)

# %%
soup = BeautifulSoup(resp.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-DE">
# <head>
# <title>
#         BestSecret – For Members Only
#     </title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <meta content="BestSecret – for Members Only" itemprop="name" property="og:title"/><meta content="Premium and luxury brands at exclusive prices. Curated collections from the world's most in-demand fashion labels — only for members." itemprop="description" name="description" property="og:description"/><meta content="https://www.bestsecret.com/home.htm" itemprop="url" property="og:url"/><meta content="https://picture.bestsecret.com/medias/sys_master/images/31591112540190.jpg" itemprop="image" property="og:image"><meta content="https://picture.bestsecret.com/medias/sys_master/images/31591112540190.jpg" property="og:image:secure_url">
# <link href="//picture.bestsecret.com" rel="dns-prefetch"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# ...
